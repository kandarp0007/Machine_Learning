# %% [markdown]
# # Task 2: Wine Dataset
# ## Roll No: 96

# %%
# Import necessary Libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing


# Naive and Gaussian model
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# For accuraccy, precision, recall
from sklearn import metrics

# %% [markdown]
# ## Import Wine Dataset and split it into Test-Train sets.

# %%
from sklearn import datasets

main_data = datasets.load_wine()
X_train, X_test, Y_train, Y_test = train_test_split(main_data.data, main_data.target, test_size = 0.2, random_state = 96)

# %% [markdown]
# ## Train Model and Predict Output

# %%
gnb = GaussianNB()
gnb.fit(X_train, Y_train)

Y_predicted = gnb.predict(X_test)

print(f"Accuracy:- {metrics.accuracy_score(Y_test, Y_predicted)}")
# Out:
# Accuracy:- 1.0

# %% [markdown]
# ## Print Classification Report

# %%
print(f"Classification report for Classifier {gnb}:\n")
print(f"{metrics.classification_report(Y_test, Y_predicted)}")
# Out:
# Classification report for Classifier GaussianNB(priors=None, var_smoothing=1e-09):
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %% [markdown]
# ## Print Confusion Matrix

# %%
disp = metrics.plot_confusion_matrix(gnb, X_test, Y_test)
disp.figure_.suptitle("Confusion Matrix")
print(f"Confusion matrix:\n{disp.confusion_matrix}")

plt.show()
# Out:
# Confusion matrix:
# [[10  0  0]
#  [ 0 14  0]
#  [ 0  0 12]]
